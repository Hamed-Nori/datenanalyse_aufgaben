# %% [markdown]
# # 💱15-Jahres-Aktiendaten: NVDA, AAPL, MSFT, GOOGL & AMZN💹
#
# ## Über den Datensatz
#
# Dies sind die historischen Aktienmarktdaten von fünf großen Big-Tech-Unternehmen: NVIDIA (NVDA), Apple (AAPL), Microsoft (MSFT), Google (GOOGL) und Amazon (AMZN) über einen Zeitraum von 15 Jahren vom 1. Januar 2010 bis zum 1. Januar 2025.
# Es enthält tägliche Aktiendaten mit Eröffnungs- und Schlusskursen, Höchst- und Tiefstkursen sowie Handelsvolumen.
# Dieser Datensatz dient als wertvolle Ressource für die Analyse langfristiger Wachstumstrends, der Volatilität und des Marktverhaltens führender Technologiegiganten.
# Durch die Analyse dieses Datensatzes können wir das historische Aktienverhalten von NVDA , AAPL , MSFT , GOOGL und AMZN über 15 Jahre besser verstehen und Vorhersagen über ihre zukünftige Performance treffen.
#
#
# ## Spaltenbeschreibung
#
#
# | Spaltenname     | Bedeutung |
# |-----------------|-----------|
# | Date            | Das Handelsdatum des Aktiendateneintrags. |
# | Close_AAPL      | Der Aktienkurs von Apple zum Börsenschluss am Ende der Handelstage. |
# | Close_AMZN      | Aktienkurs von Amazon zum Börsenschluss am Ende der Handelstage. |
# | Close_GOOGL     | Aktienkurs von Google zum Börsenschluss am Ende der Handelstage. |
# | Close_MSFT      | Aktienkurs von Microsoft am Ende der Handelstage. |
# | Close_NVDA      | NVIDIA-Aktienkurs am Ende der Handelstage. |
# | High_AAPL       | Der höchste Kurs der Apple-Aktie, der während der Handelstage erreicht wurde. |
# | High_AMZN       | Der höchste Kurs der Amazon-Aktie, der während der Handelstage erreicht wurde. |
# | High_GOOGL      | Der höchste Kurs der Google-Aktie, der während der Handelstage erreicht wurde. |
# | High_MSFT       | Der höchste Kurs der Microsoft-Aktie, der während der Handelstage erreicht wurde. |
# | High_NVDA       | Der höchste Kurs der NVIDIA-Aktie, der während der Handelstage erreicht wurde. |
# | Low_AAPL        | Der niedrigste Kurs der Apple-Aktie, der während der Handelstage erreicht wurde. |
# | Low_AMZN        | Der niedrigste Kurs der Amazon-Aktie, der während der Handelstage erreicht wurde. |
# | Low_GOOGL       | Der niedrigste Kurs der Google-Aktie, der während der Handelstage erreicht wurde. |
# | Low_MSFT        | Der niedrigste Kurs der Microsoft-Aktie, der während der Handelstage erreicht wurde. |
# | Low_NVDA        | Der niedrigste Preis, den die NVIDIA-Aktie während der Handelstage erreichte. |
# | Open_AAPL       | Eröffnungskurs der Apple-Aktie zu Beginn der Handelstage. |
# | Open_AMZN       | Eröffnungskurs der Amazon-Aktie zu Beginn der Handelstage. |
# | Open_GOOGL      | Eröffnungskurs der Google-Aktie zu Beginn der Handelstage. |
# | Open_MSFT       | Eröffnungskurs der Microsoft-Aktie zu Beginn der Handelstage. |
# | Open_NVDA       | Eröffnungskurs der NVIDIA-Aktie zu Beginn der Handelstage. |
# | Volume_AAPL     | Die Anzahl der während der Handelstage gehandelten Apple-Aktien. |
# | Volume_AMZN     | Die Anzahl der während der Handelstage gehandelten Amazon-Aktien. |
# | Volume_GOOGL    | Die Anzahl der während der Handelstage gehandelten Google-Aktien. |
# | Volume_MSFT     | Die Anzahl der während der Handelstage gehandelten Microsoft-Aktien. |
# | Volume_NVDA     | Die Anzahl der während der Handelstage gehandelten NVIDIA-Aktien. |

# %%
import pandas as pd

df = pd.read_csv('../../data/big_tech_stock_data.csv')

df.head(900)
# Out:
#            Date  Close_AAPL  Close_AMZN  Close_GOOGL  Close_MSFT  Close_NVDA  \
# 0    2010-01-04    6.440330      6.6950    15.609805   23.254051    0.423884
# 1    2010-01-05    6.451465      6.7345    15.541064   23.261557    0.430073
# 2    2010-01-06    6.348847      6.6125    15.149294   23.118809    0.432824
# 3    2010-01-07    6.337109      6.5000    14.796624   22.878376    0.424342
# 4    2010-01-08    6.379242      6.6760    14.993881   23.036165    0.425259
# ..          ...         ...         ...          ...         ...         ...
# 895  2013-07-25   13.479460     15.1700    22.109013   25.804548    0.332720
# 896  2013-07-26   13.555999     15.6005    22.050484   25.993631    0.331320
# 897  2013-07-29   13.765030     15.3050    21.973774   25.927866    0.330620
# 898  2013-07-30   13.935025     15.1205    22.189209   26.182699    0.336220
# 899  2013-07-31   13.910734     15.0610    22.110256   26.174477    0.336920
#
# ...
